# %%
# %matplotlib inline

# %%
# %run validate_features.py
# Out:
# Calculating Morphology Features
# Calculating Locomotion Features
# Calculating Posture Features
# Calculating Path Features
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/numpy/lib/shape_base.py:430: FutureWarning: in the future np.array_split will retain the shape of arrays with a zero size, instead of replacing them by `array([])`, which always has a shape of (0,).
#   FutureWarning)
# The raw input to the path is the position of each worm segment,
#             in each frame. This is shown in the plot above with all frames shown at once.
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/matplotlib/lines.py:504: RuntimeWarning: invalid value encountered in greater_equal
#   return np.alltrue(x[1:] - x[0:-1] >= 0)
# For each frame, the worm segment positions are averaged along the axes.
#             This average position is plotted above for all frames above. The centroid is calculated
# ...
